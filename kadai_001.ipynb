# %%
# !pip  install openpyxl

# %%
import  openpyxl
import  time

local_time =  time.localtime()



workbook  = openpyxl.Workbook()

ws = workbook.active

ws['B2'] = '請求書'
ws['B4'] = '株式会社ABC'
ws['B5'] = '〒101-0022 東京都千代田区神田練塀町300'
ws['B6'] = 'TEL:03-1234-5678 FAX:03-1234-5678'
ws['B7'] = '担当者名:鈴木一郎 様'

ws['F4'] = 'NO.'
ws['G4'] = '0001'
ws['F5'] = '日付'
ws['G5'] = f"{local_time.tm_year}{local_time.tm_mon:02d}{local_time.tm_mday:02d}"

ws['B10'] = '商品名'
ws['C10'] = '数量'
ws['D10'] = '単価'
ws['E10'] = '金額'

ws['B11'] = '商品A'
ws['C11'] = '2'
ws['D11'] = '10000'
ws['E11'] = '20000'

ws['B12'] = '商品B'
ws['C12'] = '1'
ws['D12'] = '15000'
ws['E12'] = '15000'

ws['E13'] = '35000'




ws['B15'] = '合計'
ws['E15'] = '35000'

ws['B16'] = '消費税'
ws['E16'] = '3500'
ws['B17'] = '税込合計'
ws['E17'] = '38500'







workbook.save(f'請求書_{local_time.tm_year}{local_time.tm_mon:02d}{local_time.tm_mday:02d}.xlsx')

# %%
import  time

local_time =  time.localtime()
print(local_time.tm_year)
print(local_time.tm_mon)
print(local_time.tm_mday)

#print(time.localtime())
# Out:
# 2026
# 9
# 17
